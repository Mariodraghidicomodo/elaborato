# %%
import pandas as pd

# %%
#prova = pd.read_csv('C:/Users/elped/OneDrive/Desktop/git_vs_code/prova-elab-ing/progetto_data_scienze/codice/final.csv')
#prova = pd.read_csv('final.csv',sep='|')

# %%
#prova.columns

# %%
#prova.head(10)

# %%
prova2 = pd.read_json('final_json.json')

# %%
prova2.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_uris', 'mana_cost', 'cmc', 'power', 'toughness', 'colors',
#        'color_identity', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
#        'oversized', 'promo', 'reprint', 'variation', 'set', 'set_name',
#        'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri',
#        'rulings_uri', 'prints_search_uri', 'collector_number', 'digital',
#        'rarity', 'flavor_text', 'card_back_id', 'artist', 'artist_ids',
#        'illustration_id', 'border_color', 'frame', 'full_art', 'textless',
#        'booster', 'story_spotlight', 'related_uris', 'edhrec_rank',
#        'all_parts', 'loyalty', 'foreignData', 'printings', 'rulings',
#        'subtypes', 'supertypes', 'text', 'type', 'types', 'uuid', 'edhrecRank',
#        'leadershipSkills', 'prices'],
#       dtype='object')

# %%
prova2.head(10)
# Out:
#   object                                    id  \
# 0   card  dbcdbf7a-9294-47ad-9f93-c16b78c7463a
# 1   card  acb3ce9b-ee4f-410a-8db3-e87aeb0a4444
# 2   card  17b2ed72-d0f0-4d8d-bb5e-dce08d157466
# 3   card  0faa9eea-fbf1-41f7-9def-1ec3d5134a53
# 4   card  ecbeac44-9392-4522-8ff5-87079386bd0a
# 5   card  2b8285b7-bd88-4a6c-bd2e-9798a1c661f8
# 6   card  1f5a1578-d5fe-4b31-bb71-3253be8775a1
# 7   card  5f6927e1-c580-483a-8e2a-6e2deb74800e
# 8   card  92bcd1ce-19b1-4d78-8b09-95242ca08d76
# 9   card  4c19926a-7792-4e0f-8418-a44f0cf5eeea
#
#                               oracle_id multiverse_ids  \
# 0  cd6250ae-9079-4a62-8a70-0d94fbac21bc             []
# 1  ab0dfae5-b9d4-417b-8a0d-2525ae3a73b9             []
# 2  7264d3b3-fd46-4ea3-a85d-f0b068c331ad             []
# 3  e6284fb3-7cf8-4730-b156-10085b70b0e8             []
# 4  43296f8b-58d9-446e-a538-1c4921552c41             []
# 5  0677f49e-f8bf-4349-af52-2ccde9287c2e             []
# ...

# %%
#provo a prendere solo i nomi delle carte(unique)
lista_nomi_unique = prova2.name.unique()

# %%
lista_nomi_unique.shape
# Out:
# (19816,)

# %%
lista_nomi_unique
# Out:
# array(['Earthshaker Giant', 'Fiendish Duo', 'Calculating Lich', ...,
#        'Blaze of Glory', 'Black Ward', 'Benalish Hero'], dtype=object)

# %%
#serach a id and image, perfetto
multiid = prova2[(prova2.name == 'Mox Jet') & (prova2.multiverse_ids.str.len() != 0)][['multiverse_ids','id']] #ok adesso il scorro fino a qundo non trovo un multiverse_ids
#multiid.multiverse_id != ['']
    #if len(x)!= 0:
    #    print(x[0])
ciao = multiid.head(1)
a = ciao.multiverse_ids
for x in a:
    print(x[0])
# Out:
# 383020

# %%
#prova2[len(prova2.multiverse_ids)!=0]

# %%
type(prova2.multiverse_ids[7]) #attenzione controllare se il passaggio da final_clean_df a final_json abbia comportato la modifica dei tipi di dati!!!!!
#in caso inserire la pulizia in streamlit
#OK NO SONO DELLO STESSO TIPO
# Out:
# list

# %%
#serach a name
multiid = prova2[(prova2.name == 'Mox Jet')] #ok adesso il scorro fino a qundo non trovo un multiverse_ids
id = 0
for x in multiid:
    #print(x)
    if len(x)!= 0:
        id = x[0]

# %%
df = pd.read_json("C:/Users/elped/OneDrive/Desktop/git_vs_code/prova-elab-ing/progetto_data_scienze/codice/final_json.json")

# %%
data.head(5)

# %%
multiids = data[(data.name == 'Mox Jet')]

# %%
multiids
# Out:
#   object                                    id  \
# 5   card  2b8285b7-bd88-4a6c-bd2e-9798a1c661f8
# 6   card  1f5a1578-d5fe-4b31-bb71-3253be8775a1
# 7   card  5f6927e1-c580-483a-8e2a-6e2deb74800e
# 8   card  92bcd1ce-19b1-4d78-8b09-95242ca08d76
#
#                               oracle_id multiverse_ids     name lang  \
# 5  0677f49e-f8bf-4349-af52-2ccde9287c2e           [-1]  Mox Jet   en
# 6  0677f49e-f8bf-4349-af52-2ccde9287c2e           [-1]  Mox Jet   en
# 7  0677f49e-f8bf-4349-af52-2ccde9287c2e       [383020]  Mox Jet   en
# 8  0677f49e-f8bf-4349-af52-2ccde9287c2e           [33]  Mox Jet   en
#
#   released_at                                                uri  \
# 5  2019-11-03  https://api.scryfall.com/cards/2b8285b7-bd88-4...
# 6  2016-10-23  https://api.scryfall.com/cards/1f5a1578-d5fe-4...
# 7  2014-06-16  https://api.scryfall.com/cards/5f6927e1-c580-4...
# 8  1993-08-05  https://api.scryfall.com/cards/92bcd1ce-19b1-4...
#
# ...

# %%
multiids.multiverse_ids.isin([[-1]])
# Out:
# 5     True
# 6     True
# 7    False
# 8    False
# Name: multiverse_ids, dtype: bool

# %%
multiids = df[(df.name == 'Mox Jet') & (df.multiverse_ids.isin([[-1]]) == False)].head(1)
if multiids.empty == True:
    df[df.name == 'Mox_Jet'].head(1)
else:
    for x in multiids.multiverse_ids:
        print(type(x))
        print(x[0])
# Out:
# <class 'list'>
# 383020

# %%
name = 'Mox Jet'
multiids = df[(df.name == name) & (df.multiverse_ids.isin([[-1]]) == False)].head(1)

# %%
multiids
# Out:
#   object                                    id  \
# 7   card  5f6927e1-c580-483a-8e2a-6e2deb74800e
#
#                               oracle_id multiverse_ids     name lang  \
# 7  0677f49e-f8bf-4349-af52-2ccde9287c2e       [383020]  Mox Jet   en
#
#   released_at                                                uri  \
# 7  2014-06-16  https://api.scryfall.com/cards/5f6927e1-c580-4...
#
#                                         scryfall_uri  layout  ...  \
# 7  https://scryfall.com/card/vma/6/mox-jet?utm_so...  normal  ...
#
#                  rulings       subtypes       supertypes           text  \
# 7  [no additional rules]  [no subtypes]  [no supertypes]  {T}: Add {B}.
#
#        type       types                                  uuid edhrecRank  \
# 7  Artifact  [Artifact]  911999c5-131c-56f3-8180-379b3b8d43da      19159
#
#   leadershipSkills                                             prices
# 7         unusable  {'mtgo': {}, 'mtgoFoil': {}, 'paper': {'2019-1...
#
# ...

# %%
for x in range(10,30,3):
    print(x)
# Out:
# 10
# 13
# 16
# 19
# 22
# 25
# 28

# %%
#CREARE TITOLO AX

#if finish-start>10: #ogni due anni
    #ax = plt.title(f'amount of type from {val}-01-01 to {val + 2}-12-31')
#    val = val + 3
#else:
#    ax = plt.title(f'amount of type from {val}-01-01 to {val}-12-31')
#    val = val + 1

# %%
#righe = 0
#if len(list_mask_data) %2 != 0:
#    righe = int(len(list_mask_data)/2+0.5)
#    print('righe = ', righe)
#else:
#    righe = int(len(list_mask_data)/2)
#    print('righe = ', righe)
#fig, axs = plt.subplots(nrows= righe, ncols=2)
#count=0
#colonna = 0

#axs[count,colonna].bar(list_amount_type.keys(),list_amount_type.values(), labels = list_amount_type.keys())
#if colonna > 0:
#    colonna = 0
#    count = count + 1
#else:
#    colonna = colonna + 1

# %%
# FIG WITH MULTI AX

#fig_nc = plt.figure(figsize=(20,60))
#count = 0
    
#for x in list_mask_data:
    #ax = fig_nc.add_subplot(len(list_mask_data),1,count+1)
    #ax = plt.title(f'amount of cards based on released period')
    #ax = plt.ylabel('amount')
    #ax = plt.xlabel('period')
    #ax = plt.bar(final_df[x].released_at.value_counts().index,final_df[x].released_at.value_counts())
    #count = count + 1
#st.pyplot(fig_nc)
